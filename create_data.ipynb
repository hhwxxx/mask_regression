# %%
import numpy as np
from PIL import Image, ImageDraw
import random
import os
import pandas as pd

# %%
height = 256
width = 256
shape = (height, width)

# %%
# Rectangle
save_dirs = ['/home/hhw/work/hikvision/mask_data/rectangle/train', 
            '/home/hhw/work/hikvision/mask_data/rectangle/val',
            '/home/hhw/work/hikvision/mask_data/rectangle/test']
csv_files = ['/home/hhw/work/hikvision/mask_data/rectangle/train.csv',
            '/home/hhw/work/hikvision/mask_data/rectangle/val.csv',
            '/home/hhw/work/hikvision/mask_data/rectangle/test.csv']
NUM_IMAGES = [5000, 1500, 2000]


csv_columns = ['filename', 'top_left_height', 'top_left_width', 'top_right_height', 'top_right_width',
               'bottom_left_height', 'bottom_left_width', 'bottom_right_height', 'bottom_right_width']


for save_dir, csv_file, NUM_IMAGE in zip(save_dirs, csv_files, NUM_IMAGES):
    num_image = 0
    df = pd.DataFrame(columns=csv_columns)
    while True:
        image = np.zeros(shape, np.uint8)
    
        # create mask coordinates
        top_left_height = random.randint(0, height - 1)
        top_left_width = random.randint(0, width - 1)
        top_right_height = top_left_height
        top_right_width = random.randint(top_left_width, width - 1)
        bottom_left_height = random.randint(top_left_height, height - 1)
        bottom_left_width = top_left_width
        bottom_right_height = bottom_left_height
        bottom_right_width = top_right_width
    
        assert top_right_width >= top_left_width
        assert bottom_left_height >= top_left_height
    
        if bottom_right_height - top_left_height < 50 or bottom_right_width - top_left_width < 50:
            continue
    
        # Point is represented as (width, height) in PIL.
        top_left = (top_left_width, top_left_height)
        top_right = (top_right_width, top_right_height)
        bottom_left = (bottom_left_width, bottom_left_height)
        bottom_right = (bottom_right_width, bottom_right_height)
    
        if not os.path.exists(save_dir):
            os.makedirs(save_dir)
    
        image = Image.fromarray(image)
        draw = ImageDraw.Draw(image)
        draw.polygon([top_left, top_right, bottom_right, bottom_left], fill=255, outline=255)
    
        filename = os.path.join(save_dir, '{:06d}.png'.format(num_image))
        image.save(filename, 'PNG')
    
        df = df.append(
            pd.DataFrame(
                [[filename, top_left_height, top_left_width, top_right_height, top_right_width,
                  bottom_left_height, bottom_left_width, bottom_right_height, bottom_right_width]], 
                columns=csv_columns), ignore_index=True)
    
        print('Creating {:06d} image.'.format(num_image))
        num_image += 1
        if num_image == NUM_IMAGE:
            break
            
    df.to_csv(csv_file)
    print('Finished!')
# Out:
# Creating 000000 image.
# Creating 000001 image.
# Creating 000002 image.
# Creating 000003 image.
# Creating 000004 image.
# Creating 000005 image.
# Creating 000006 image.
# Creating 000007 image.
# Creating 000008 image.
# Creating 000009 image.
# Creating 000010 image.
# Creating 000011 image.
# Creating 000012 image.
# Creating 000013 image.
# Creating 000014 image.
# Creating 000015 image.
# Creating 000016 image.
# Creating 000017 image.
# Creating 000018 image.
# Creating 000019 image.
# Creating 000020 image.
# Creating 000021 image.
# Creating 000022 image.
# Creating 000023 image.
# Creating 000024 image.
# Creating 000025 image.
# Creating 000026 image.
# Creating 000027 image.
# Creating 000028 image.
# Creating 000029 image.
# Creating 000030 image.
# Creating 000031 image.
# Creating 000032 image.
# Creating 000033 image.
# Creating 000034 image.
# Creating 000035 image.
# Creating 000036 image.
# Creating 000037 image.
# Creating 000038 image.
# Creating 000039 image.
# ...

# %%
    image = np.zeros(shape, np.uint8)
    
    # create mask coordinates
    top_left_height = random.randint(0, height - 1)
    top_left_width = random.randint(0, width - 1)
    top_right_height = random.randint(0, height - 1)
    top_right_width = random.randint(top_left_width, width - 1)
    bottom_left_height = random.randint(max(top_left_height, top_right_height), height - 1)
    bottom_left_width = random.randint(0, width - 1)
    bottom_right_height = bottom_left_height + (top_right_height - top_left_height)
    bottom_right_width = bottom_left_width + (top_right_width - top_right_width)
    
    assert top_right_width >= top_left_width
    assert bottom_left_height >= top_left_height
    assert bottom_right_height >= top_right_height
    assert bottom_right_width >= bottom_left_width
    
    
    # if bottom_right_height - top_left_height < 50 or bottom_right_width - top_left_width < 50:
    #     continue
    
    top_left = (top_left_height, top_left_width)
    top_right = (top_right_height, top_right_width)
    bottom_left = (bottom_left_height, bottom_left_width)
    bottom_right = (bottom_right_height, bottom_right_width)
    

    
    image = Image.fromarray(image)
    draw = ImageDraw.Draw(image)
    draw.polygon([top_left[::-1], top_right[::-1], bottom_right[::-1], bottom_left[::-1]], outline=50)
    draw.line([top_left[::-1], top_right[::-1]], fill=255)
    image
# Out:
# <PIL.Image.Image image mode=L size=512x512 at 0x7FC8836A1950>
